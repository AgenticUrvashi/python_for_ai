# %% [markdown]
# ### class 24:

# %%
person = ("shweta",18,"nagpur")
print(person)
# Out:
# ('shweta', 18, 'nagpur')

# %% [markdown]
# ### immmutable

# %%
person = ("shweta",18,"nagpur")
person[1]=19
print(person)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 person = ("shweta",18,"nagpur")
# ----> 2 person[1]=19
#       3 print(person)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# list and tuple
# mutable and immutable
# marks,msg and

# %% [markdown]
# ## unpaking

# %% [markdown]
# person = ("shweta",18,"nagpur")
# name,age,city = person
