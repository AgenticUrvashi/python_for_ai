# %% [markdown]
# ### class:21

# %% [markdown]
# **que01:** 5 favourite movies ki list banao, pehli aur aakhri print karo.

# %%
movie = ["3 idiots","golmal","dangal","PK","welcome"]
print(movie[0])
print(movie[4])
# Out:
# 3 idiots
# welcome

# %% [markdown]
# **que02:** [10,20,30,40,50,60] mein se beech ke 3 numbers slice karo.

# %%
list=[10,20,30,40,50,60]
print(list[2:5])
print(list[1:4])
# Out:
# [30, 40, 50]
# [20, 30, 40]

# %% [markdown]
# **que03:** Kisi bhi list ko [::-1] se ulta karke print karo.

# %%
list=[10,20,30,40,50,60]
print(list[::-1])
# Out:
# [60, 50, 40, 30, 20, 10]

# %% [markdown]
# ## class 22

# %% [markdown]
# **que01:** Khaali list mein 5 numbers append karo, phir max, min, aur average print karo.

# %%
list = []
list.append(45)
list.append(67)
list.append(87)
list.append(90)
list.append(43)

print(max(list))
print(min(list))
print(sum(list)/len(list))
# Out:
# 90
# 43
# 66.4

# %% [markdown]
# **que02:** Ek list ko sorted() se sort karo BINA original badle (dono print karke dikhao).

# %%
list = [25,67,45,78,83]

new_list = sorted(list)
print(new_list)
print(list)
# Out:
# [25, 45, 67, 78, 83]
# [25, 67, 45, 78, 83]

# %% [markdown]
# **que03:** Ek list se pop() se aakhri item nikaalo aur use print karo.

# %%
list = [47,78,91,56]
list.pop()
print(list)
# Out:
# [47, 78, 91]

# %% [markdown]
# ## class 23

# %% [markdown]
# **que01:** Ek 2x2 grid banao aur grid[0][1] aur grid[1][0] print karo.

# %%
grid = [
    [1,5],
    
    [4,9]
]

print(grid[0][1])
print(grid[1][0])
# Out:
# 5
# 4

# %% [markdown]
# **que02:** 3 students ka naam aur 3 subjects ke marks rakho; har student ka total print karo.

# %%
list = [

    ["shweta",89,94,84],
    ["janu",67,82,90],
    ["ravi",78,87,65],

]

for row in list:
        print(f"{row[0]} : total = {sum(row[1:5])}", end=" ")

        print()
# Out:
# shweta : total = 267
# janu : total = 239
# ravi : total = 230

# %% [markdown]
# **que03:** Ek 3x3 grid ke saare items nested loop se print karo.

# %%
grid = [
    [45,78,67],
    [56,87,91],
    [34,67,89],
]

for row in grid:
    for col in row:
        print(col, end=" ")

    print()
# Out:
# 45 78 67
# 56 87 91
# 34 67 89

# %%
list = [[23,55,[90,92],[1,2,3,"urvashi"],[78]]]
list[0][3][3]
# Out:
# 'urvashi'

# %% [markdown]
# ## class 24

# %% [markdown]
# **que01:** Ek tuple banao ("Rahul", 17, "Delhi") aur teeno values unpack karke print karo.

# %%
men = ("Rahul",17,"Delhi")
name,age,city = men
print(name,age,city)
# Out:
# Rahul 17 Delhi

# %% [markdown]
# **que02:** Do variables ko swap karo bina temp variable ke.

# %%
a = 78
b = 90
a,b = b,a
print(f"A={a} , B={b}")
# Out:
# A=90 , B=78

# %% [markdown]
# **que03:** Try karo tuple ka koi item badalne ki — error padho aur ek line likho kyun aaya.

# %%
men = ("rahul",17,"delhi")
men[1]=18
print(men)

##ye error kahta hai ki tuple immutable hai.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 men = ("rahul",17,"delhi")
# ----> 2 men[1]=18
#       3 print(men)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## class 25

# %% [markdown]
# **que01:** User se sentence lo, usme kitne words hain print karo (.split() + len).

# %%
user_input=input("enter the sentence: ")
list = user_input.split(" ")
print(list)
print(len(list))
# Out:
# ['hi', 'i', 'am', 'urvashi']
# 4

# %% [markdown]
# **que02:** Ek comma-separated string ko list mein todo, phir " - " se dobara jodo.

# %%
female = "asha,18,nagpur"
list = print(female.split(","))
"-".join("asha,18,nagpur")
# Out:
# ['asha', '18', 'nagpur']
# 'a-s-h-a-,-1-8-,-n-a-g-p-u-r'

# %% [markdown]
# **que03:** Check karo "level" aur "python" palindrome hain ya nahi.

# %%
word1 = "level"
word2 = "python"
if word1 == word1[::-1]:
    print("palindrome")
else:
    ("not palindrome")
if word2==word2[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome
# not palindrome
