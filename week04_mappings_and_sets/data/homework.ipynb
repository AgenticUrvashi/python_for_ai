# %% [markdown]
# ## class 26

# %% [markdown]
# **que01:** Apna ek dictionary banao: name, age, city, favourite_subject. Sab print karo.

# %%
person={
    "name": "urvashi",
    "age": 17,
    "city":"nagpur",
    "fav_subject": "python",
    }

print(person["name"])
print(person["age"])
print(person["city"])
print(person["fav_subject"])
# Out:
# urvashi
# 17
# nagpur
# python

# %% [markdown]
# **que02:** Usme ek nayi key dream_job add karo aur age update karo.

# %%
person["dream_job"] = "agentic_ai_engineer"

person["age"] = 18

print(person)
# Out:
# {'name': 'urvashi', 'age': 18, 'city': 'nagpur', 'fav_subject': 'python', 'dream_job': 'agentic_ai_engineer'}

# %% [markdown]
# **que03:** in se check karo ki city key hai ya nahi.

# %%
print("city" in person)
# Out:
# True
