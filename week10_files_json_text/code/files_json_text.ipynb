# %% [markdown]
# # CLASS 56 — Reading & Writing Files

# %% [markdown]
# ### Concept 1 — file mein likhna (with open)
#  Technical definition — File handling with open(): open() returns a file object connected to a file on disk, opened in a given mode. Using it with a with statement (a context manager) guarantees the file is automatically closed when the block ends, flushing any written data safely.

# %%
with open('my_first_file.txt','w') as f:
    text = "hello, you are my first file."
    f.write(text)

# %% [markdown]
# ### Concept 2 — modes (w vs a vs r)
# 📖 Technical definition — File mode: A file mode is the string passed to open() that sets how the file is used: "r" reads an existing file, "w" writes and overwrites all existing content, and "a" appends new content to the end while keeping the old content.

# %% [markdown]
# Mode|	Matlab	    |Dhyaan
# "r"	|Read (padho)	|Default. File na ho toh error.
# "w"	|Write (likho)	|Purana sab MITA deta hai!
# "a"	|Append (jodo)	|End mein add karta hai, purana safe

# %% [markdown]
# ### Concept 3 — file padhna

# %%
with open('my_first_file.txt','r') as f:
    data = f.read()

# %%
data
# Out:
# 'hello, you are my first file.\nthis is second line.\nyou are learning python with Indian AI Production.'

# %%
with open('my_first_file.txt','r') as f:
    data = f.read()
    for line in data.split("/n"):
        print(line)
# Out:
# hello, you are my first file.
# this is second line.
# you are learning python with Indian AI Production.

# %%
with open('my_first_file.txt','r') as f:
    for line in f:
        print(line.strip())
# Out:
# hello, you are my first file.
# this is second line.
# you are learning python with Indian AI Production.

# %% [markdown]
# ### Concept 4 — append mode (data jodo)

# %%
with open('my_first_file.txt','a') as f:
    f.write("\nThis text append by append mode.")

# %% [markdown]
# ### Concept 5 — UTF-8 (Python 3.15)

# %%
with open('my_first_file.txt','w',encoding="utf-8") as f:
    f.write("❤🤎💜🖤hii")

# %%
with open('my_first_file.txt','r',encoding="utf-8") as f:
    f.read()

# %% [markdown]
# ### small project : Diary

# %%
def add_entry(text:str)->None:
    with open('diary.txt','a') as f:
        f.write(text + "\n")

def read_diary()->str:
    with open('diary.txt','r') as f:
        for line in f:
            print(line.strip())

add_entry("I am learning python with Indian AI Production at 9AM")
add_entry("Lunch break at 12PM")

# %%
add_entry("I have completed the first chapter of the book at 10PM")
add_entry("I am going to sleep at 11PM")

# %%
read_diary()
# Out:
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM

# %% [markdown]
# ### concept 6 : w,r,a in different way

# %%
f = open('diary.txt','a')
f.write("this is a test")
f.close()

# %% [markdown]
# ### Common mistakes

# %%
# 'w' se galti se data udaana
with open("important.txt", "w") as f:    # ❌ purana sab gaya!
    f.write("new")                        # append chahiye tha toh "a"

# with ke bina (file band karna bhool jaana)
f = open("a.txt", "w")
f.write("hi")
# f.close() bhool gaye → data shayad save na ho. 'with' use karo hamesha.

# %% [markdown]
# # CLASS 57 — pathlib & Safe Paths

# %% [markdown]
# ### Concept 1 — pathlib.Path (modern path handling)
# 📖 Technical definition — pathlib.Path: pathlib.Path is an object-oriented representation of a filesystem path. It joins paths with the / operator in an OS-independent way and provides methods to inspect, read, write, and resolve files and directories.

# %%
from pathlib import Path

# %%
file_path = "data/diary.txt"

with open(file_path, "r") as f:
    print(f.read())
# Out:
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# this is a test

# %%
file_path = Path("data") / "diary.txt"
with open(file_path,'r') as f:
    print(f.read())
# Out:
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# this is a test

# %%
file_path
# Out:
# WindowsPath('data/diary.txt')

# %%
file_path.name
# Out:
# 'diary.txt'

# %%
file_path.suffix
# Out:
# '.txt'

# %%
file_path.parent
# Out:
# WindowsPath('data')

# %%
file_path.exists()
# Out:
# True

# %%
file_path_2 = Path("data") / "diary_2.txt"

# %%
file_path_2.exists()
# Out:
# False

# %%
if file_path_2.exists():
    with open(file_path_2,'r') as f:
        print(f.read())

# %%
with open(file_path_2,'r') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 with open(file_path_2,'r') as f:
#       2     print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\diary_2.txt'

# %% [markdown]
# ### Concept 2 — files/folders banana aur padhna

# %%
folder = Path("utils")
folder.mkdir(exist_ok=True)

# %%
folder = Path("utils")
folder.mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[16], line 2
#       1 folder = Path("utils")
# ----> 2 folder.mkdir()
#
# File ~\AppData\Local\Programs\Python\Python315\Lib\pathlib\__init__.py:1210, in Path.mkdir(self, mode, parents, exist_ok, parent_mode)
#    1206 """
#    1207 Create a new directory at this given path.
#    1208 """
#    1209 try:
# -> 1210     os.mkdir(self, mode)
#    1211 except FileNotFoundError:
#    1212     if not parents or self.parent == self:
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'utils'

# %%
file = folder / 'my_utils.txt'
file.write_text("This text is written by pathlib", encoding = "utf-8")
# Out:
# 31

# %%
file.read_text()
# Out:
# 'This text is written by pathlib'

# %% [markdown]
# ### Concept 3 — folder ki files list karo

# %%
parent_folder = Path("utils")
txt_files = parent_folder.glob("*.txt")

# %%
txt_files

# %%
list(txt_files)
# Out:
# [WindowsPath('utils/my_utils.txt'),
#  WindowsPath('utils/my_utils_copy.txt'),
#  WindowsPath('utils/my_utils_copy_1.txt')]

# %%
for file_path in parent_folder.glob("*.txt"):
    print(file_path.name)
# Out:
# my_utils.txt
# my_utils_copy.txt
# my_utils_copy_1.txt

# %%
for file_path in parent_folder.glob("*copy*.txt"):
    print(file_path.name)
# Out:
# my_utils_copy.txt
# my_utils_copy_1.txt

# %%
for file_path in parent_folder.glob("../*.txt"):
    print(file_path.name)
# Out:
# diary.txt
# my_first_file.txt

# %%
file_name = input("enter the file you want to use from utils folder:")
file_path = parent_folder / file_name
file_path.read_text()
# Out:
# 'This text is written by pathlib'

# %%
file_name = input("enter the file you want to use from utils folder:")
file_path = parent_folder / file_name
file_path.read_text()
# Out:
# 'I am learning python with Indian AI Production at 9AM\nLunch break at 12PM\nI have completed the first chapter of the book at 10PM\nI am going to sleep at 11PM\nI am learning python with Indian AI Production at 9AM\nLunch break at 12PM\nI am learning python with Indian AI Production at 9AM\nLunch break at 12PM\nI have completed the first chapter of the book at 10PM\nI am going to sleep at 11PM\nthis is a test'

# %% [markdown]
# ### Concept 4 — SECURITY: path traversal se bachna
# Technical definition — Path traversal: Path traversal is a security vulnerability where untrusted input containing sequences like ../ is used to escape an intended directory and access files elsewhere on the system. It is prevented by resolving the final absolute path and confirming it stays inside an allowed base folder.

# %%
base_folder = Path("utils").resolve()
file_name = input("enter the file you want to use from utils folder: ")
file_path = (base_folder / file_name).resolve()

if file_path.is_relative_to(base_folder):
    data = file_path.read_text()
    print(data)

else:
    print("Access denied")
# Out:
# This text is written by pathlib

# %%
base_folder = Path("utils").resolve()
file_name = input("enter the file you want to use from utils folder: ")
file_path = (base_folder / file_name).resolve()

if file_path.is_relative_to(base_folder):
    data = file_path.read_text()
    print(data)

else:
    print("Access denied")
# Out:
# Access denied

# %% [markdown]
# ### Common mistakes

# %%
# user input seedhe path mein — KHATARNAK
filename = input("File: ")
open(filename)               # ❌ user '../../etc/passwd' daal sakta hai

# string concatenation se path (OS-unsafe)
path = "data" + "/" + "file.txt"     # ❌ Path("data") / "file.txt" use karo

# %% [markdown]
# # CLASS 58 — JSON

# %% [markdown]
# ###  Concept 1 — JSON dikhta kaise hai?
#  Technical definition — JSON: JSON (JavaScript Object Notation) is a lightweight, text-based data format for storing and exchanging structured data as key–value objects and arrays. It is language-independent and is the standard format used by web and LLM APIs.

# %%
# JDON data

{
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':true
}

# %%
# python dict

{
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':true
}

# %%
JSON : true,false,null >>> Python : True,False,None

# %% [markdown]
# ### Concept 2 — Python → JSON string (dumps)
#  Technical definition — Serialization / deserialization: Serialization converts an in-memory Python object into a JSON text form (json.dumps to a string, json.dump to a file). Deserialization is the reverse, parsing JSON text back into Python objects (json.loads from a string, json.load from a file).

# %%
import json

# %%
data = {
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':True
}

json_str = json.dumps(data)

# %%
type(data)
# Out:
# dict

# %%
json_str
# Out:
# '{"name": "Asha", "age": 17, "sub": ["math", "sci"], "is_student": true}'

# %%
type(json_str)
# Out:
# str

# %% [markdown]
# ### Concept 3 — JSON string → Python (loads)

# %%
data_de_dict = json.loads(json_str)

# %%
data_de_dict
# Out:
# {'name': 'Asha', 'age': 17, 'sub': ['math', 'sci'], 'is_student': True}

# %%
type(data_de_dict)
# Out:
# dict

# %%
data_de_dict["name"]
# Out:
# 'Asha'

# %%
data_de_dict["is_student"]
# Out:
# True

# %% [markdown]
# ### Concept 4 — file ke saath JSON (dump/load)

# %%
data = {
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':True
}

with open("student_record.json",'w') as f:
    json.dump(data,f,indent=3)

# %%
with open("student_record.json",'r') as f:
    data_from_file = json.load(f)

# %%
data_from_file
# Out:
# {'name': 'Asha', 'age': 17, 'sub': ['math', 'sci'], 'is_student': True}

# %%
data_from_file["sub"]
# Out:
# ['math', 'sci']

# %%
data = {
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':True
}

with open("student_record.json",'w') as f:
    json.dumps(data,f,indent=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       5     'is_student':True
#       6 }
#       7
#       8 with open("student_record.json",'w') as f:
# ----> 9     json.dumps(data,f,indent=3)
#
# TypeError: dumps() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given

# %%
data = {
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':True
}

with open("student_record.json",'w') as f:
    json.dumps(data)

# %%
data = {
    'name':"Asha",
    'age':17,
    'sub':['math','sci'],
    'is_student':True
}

with open("student_record.json",'w') as f:
    json.dump(data,f,indent=3)

# %% [markdown]
# ### MINI project: Save agent chat history

# %%
# history = [
#     {"role":"user", "content": "Hello"},
#     {"role":"assistant", "content": "Hi! How are you?"},
# ]

def create_history()->None:
    with open("agent_chat_history.json","w") as f:
        json.dump([],f,indent=4)

def add_history(role:str,content:str)->None:
    with open("agent_chat_history.json",'r') as f:
        history = json.load(f)

    history.append({"role":role,"content":content})

    with open("agent_chat_history.json","w") as f:
        json.dump(history,f,indent=4)

def read_history()->list:
    with open("agent_chat_history.json",'r') as f:
        print(json.load(f))

# with open("agent_chat_history.json","r") as f:
#     history_from_file = json.load(f)

# with open("agent_chat_history.json","w") as f:
#     history_from_file.append({"role":"student","content": "I am a student"})
#     json.dump(history_from_file,f,indent=4)

# %%
create_history()

# %%
add_history("user","Hi ,how are you")

# %%
add_history("system","act as a developer")

# %%
read_history()
# Out:
# [{'role': 'user', 'content': 'Hi ,how are you'}, {'role': 'system', 'content': 'act as a developer'}]

# %% [markdown]
# ### Common mistakes

# %%
import json
# dumps vs dump confuse karna
json.dump(data)          # ❌ dump ko file chahiye: json.dump(data, f)
json.dumps(data, f)      # ❌ dumps ko file nahi chahiye: json.dumps(data)

# invalid JSON load karna
json.loads("{'name': 'Asha'}")   # ❌ JSON ko DOUBLE quotes chahiye, single nahi

# %% [markdown]
# # CLASS 59 — CSV & Regex

# %% [markdown]
# ### Concept 1 — CSV (comma-separated values)
#  Technical definition — CSV: CSV (Comma-Separated Values) is a plain-text tabular format where each line is a row and columns are separated by commas. Python's csv module reads and writes it, with DictReader mapping each row to a dictionary keyed by the header.

# %% [markdown]
# CSV = comma seperated values

# %% [markdown]
# Regex = regular expression

# %%
import csv

rows = [
    ["Name", "Marks"],
    ["Asha", 85],
    ["Rahul", 90]
]

with open("marks.csv","w",newline ="",encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
# wrong way to store data in csv

rows =[
    {"a":1,"b":2,"c":3},
    {"a":4,"b":5,"c":6}
]

with open("marks_2.csv","w",newline ="",encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
with open("marks.csv","r",encoding="utf-8") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Marks']
# ['Asha', '85']
# ['Rahul', '90']

# %% [markdown]
# ### Concept 2 — CSV as dictionaries (zyada readable)

# %%
with open('marks.csv','r',encoding="utf-8") as f:
    reader = csv.DictReader(f)

# %%
reader

# %%
with open('marks.csv','r',encoding="utf-8") as f:
    reader = csv.DictReader(f) 
    for row_dict in reader:
        print(row_dict["Name"],row_dict["Marks"])
# Out:
# Asha 85
# Rahul 90

# %%
# reader >>
# [
#     {"Name": "Asha", "Marks":"85"},
#     {"Name": "Rahul", "Marks":"90"}
# ]

# %% [markdown]
# ### Concept 3 — Regex (patterns dhoondhna)
#  Technical definition — Regular expression (regex): A regular expression is a compact pattern language for matching, searching, and replacing text. Python's re module uses these patterns via functions such as search (first match), findall (all matches), and sub (replace matches).

# %%
import re

# %%
text = """My contact: email >> urvashifromindianaiproduction_help@gmail.com, 
        and my mobile no >> 34556778765, my secondary mobile no >> 9238247523."""

nums = re.findall(r"\d+", text)
print(nums)
# Out:
# ['34556778765', '9238247523']

# %%
nums = re.search(r"\d+", text)
print(nums)
# Out:
# <re.Match object; span=(96, 107), match='34556778765'>

# %%
list_word = text.split(" ")

# %%
def get_email(text):
    list_word = text.split(" ")

    for word in list_word:
        if "@" in word:
            print(word)

# %%
get_email(text)
# Out:
# urvashifromindianaiproduction_help@gmail.com,

# %%
nums = re.search(r"\d+", text)
print(nums.group())
# Out:
# 34556778765

# %%
email = re.search(r"\w+@\w+\.\w+", text)

print(email.group())
# Out:
# urvashifromindianaiproduction_help@gmail.com

# %% [markdown]
# ### Concept 4 — common regex patterns

# %%
text = "I have 3 cats and 12 dogs. #pets #animals"

print(re.findall(r"\d+", text))       # ['3', '12']        — numbers
print(re.findall(r"#\w+", text))      # ['#pets', '#animals'] — hashtags
print(re.sub(r"\d+", "N", text))      # I have N cats and N dogs...  — replace

# %% [markdown]
# ### Common mistakes

# %%
import re
# raw string bhool jaana
re.findall("\d+", text)      # ⚠️ kaam kar sakta hai par r"\d+" likho — safe habit

# search None de toh .group() crash
m = re.search(r"\d+", "no digits here")
print(m.group())             # ❌ AttributeError — pehle check karo: if m:

# %% [markdown]
# # CLASS 60 — subprocess & logging (Project Class)

# %% [markdown]
# ### Concept 1 — subprocess (commands chalana)
#  Technical definition — subprocess: The subprocess module runs external programs from Python as separate processes and can capture their output and exit code. Passing the command as a list of arguments (rather than a shell string) avoids shell interpretation and command-injection risks.

# %%
import subprocess

# %%
result = subprocess.run(["python","--version"], capture_output=True, text=True)

# %%
result
# Out:
# CompletedProcess(args=['python', '--version'], returncode=0, stdout='Python 3.15.0b3\n', stderr='')

# %%
result.stdout
# Out:
# 'Python 3.15.0b3\n'

# %%
result = subprocess.run(["git","--version"], capture_output=True, text=True)

# %%
print(result.stdout)
# Out:
# git version 2.55.0.windows.1

# %%
result = subprocess.run(["cmd","/c","dir"], capture_output=True, text=True)
print(result.stdout)
# Out:
#  Volume in drive G is New Volume
#  Volume Serial Number is 4413-65C4
#
#  Directory of g:\Urvashi\python_indian_ai_production\python_for_ai\week10_files_json_text\code
#
# 08/26/2026  01:16 PM    <DIR>          .
# 08/26/2026  01:16 PM    <DIR>          ..
# 08/26/2026  09:01 AM               164 agent_chat_history.json
# 08/25/2026  08:47 AM               656 c56_hw_1_three_goals.py
# 08/25/2026  08:55 AM               587 c56_hw_2_4th_goal.py
# 08/26/2026  11:10 AM               568 c57_hw_1.py
# 08/26/2026  11:24 AM               783 c57_hw_2.py
# 08/26/2026  12:11 PM             1,187 c57_hw_3.py
# 08/26/2026  12:22 PM               911 c58_hw_1.py
# 08/26/2026  12:33 PM               539 c58_hw_2.py
# 08/26/2026  12:58 PM             1,058 c58_hw_3.py
# 08/26/2026  10:19 AM    <DIR>          data
# 08/24/2026  08:16 PM               412 diary.txt
# 08/26/2026  03:45 PM            39,504 files_json_text.ipynb
# 08/26/2026  10:20 AM    <DIR>          hw
# 08/26/2026  01:13 PM                31 marks.csv
# 08/26/2026  01:16 PM                14 marks_2.csv
# 08/24/2026  07:53 PM               203 my_first_file.txt
# 08/26/2026  08:46 AM               110 student_record.json
# 08/25/2026  07:03 PM    <DIR>          utils
#               15 File(s)         46,727 bytes
#                5 Dir(s)  283,426,041,856 bytes free

# %% [markdown]
# ### Concept 2 — SECURITY: shell=True se bachо

# %% [markdown]
#  ❌ KHATARNAK — user input + shell=True

# %%
# user_input = "test.txt; rn -rf /"
# subprocess.run(f"cat {user_input}", shell=True) 


#rm -rf /: A notoriously destructive command:
#rm: Remove (delete) files/folders.
#-r (recursive): Delete folders and everything inside them.
#-f (force): Force delete without prompting for confirmation.
#/: The root directory (entire hard drive/system).

# %%
path = r"diary.txt"
# Run command and capture output cleanly
result = subprocess.run(["cmd", "/c", "type", path], capture_output=True, text=True)
print(result.stdout)
# Out:
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I am learning python with Indian AI Production at 9AM
# Lunch break at 12PM
# I have completed the first chapter of the book at 10PM
# I am going to sleep at 11PM
# this is a test

# %% [markdown]
# ### Concept 3 — logging (print se behtar)
# Technical definition — Logging: Logging is the practice of recording structured, timestamped messages about a program's execution at severity levels (such as INFO, WARNING, ERROR). Unlike print, it can be filtered by level and routed to files, and sensitive data must never be logged.

# %%
import logging

# %%
logging.basicConfig(level=logging.INFO, format = "%(asctime)s - %(levelname)s - %(message)s")

# %%
logging.info("Program started")
print("Progarm started")
# Out:
# 2026-08-26 16:03:56,636 - INFO - Program started
# Progarm started

# %%
logging.info("Program started")
logging.warning("Low memory")
logging.error("Somthing failed or no space to store message")
# Out:
# 2026-08-26 16:06:38,627 - INFO - Program started
# 2026-08-26 16:06:38,628 - WARNING - Low memory
# 2026-08-26 16:06:38,630 - ERROR - Somthing failed or no space to store message

# %% [markdown]
# ### Concept 4 — SECURITY: secrets kabhi log mat karo

# %%
my_password = "enrkdsfkjofsdfofnTTTWA*"

logging.info(f"User logging successfull with password {my_password}")
logging.info("User logging successfull with password ********")
# Out:
# 2026-08-26 16:10:55,110 - INFO - User logging successfull with password enrkdsfkjofsdfofnTTTWA*
# 2026-08-26 16:10:55,112 - INFO - User logging successfull with password ********

# %% [markdown]
# ### Common mistakes

# %%
# shell=True with user input (command injection)
subprocess.run(user_text, shell=True)        # ❌ never

# secret logging
logging.info(f"password={password}")          # ❌ never log secrets

# print ki jagah logging na use karna bade apps mein
print("error happened")                       # bade apps mein logging.error() use karo
