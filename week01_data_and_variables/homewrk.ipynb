# %% [markdown]
# ### class11

# %% [markdown]
# **que01:** Inhe achhe naam wale variables mein store karke print karo: apna name, age, city, favourite subject, dream job.

# %%
name = "urvashi"
age = 24
city = "nagpur"
fav_subject = "maths"
dream_job = "agentic_ai_engineer"
print(name)
# Out:
# urvashi

# %% [markdown]
# ### class12

# %% [markdown]
# **que02:** Radius 7 wale circle ka area nikalo (use 3.14159 * 7 ** 2).

# %%
radius = 7
pi = 3.14
area = pi*radius**2
print(area)
# Out:
# 153.86

# %% [markdown]
# **que03:** % use karke check karo ki 2026 ko 4 se divide karne par remainder 0 aata hai ya nahi.

# %%
print(2026%4)
# Out:
# 2

# %% [markdown]
# ### class13

# %% [markdown]
# **que01:** Apna name aur city store karke f-string se print karo "Hi, I am ___ from ___."

# %%
print(f"Hi,I am {name} from {city}")
# Out:
# Hi,I am urvashi from nagpur

# %% [markdown]
# **que02:** cost = 250 aur qty = 4 store karke total f-string se print karo.

# %%
cost = 250
qty = 4
print(f"the total is {cost*4}")
# Out:
# the total is 1000

# %% [markdown]
# **que03:** marks = 367 store karo, 450 mein se percentage 2 decimals ke saath print karo.

# %%
marks = 367
total = 450
percentage = marks/total*100

print(f"the percentage is {percentage:.2f}")
# Out:
# the percentage is 81.56

# %% [markdown]
# ### class14

# %% [markdown]
# **que01:** Do boolean variables banao aur unpar and, or, not ka result print karo.

# %%
is_weekand = False
is_working_day = True

print(is_weekand and is_working_day)
print(is_weekand or is_working_day)
print(not is_weekand)
# Out:
# False
# True
# True

# %% [markdown]
# **que02:** String "45" ko number mein convert karke 5 add karo.

# %%
print(int("45")+5)
# Out:
# 50

# %% [markdown]
# **que03:** Predict phir check karo: 10 == 10.0 → True ya False? int(7.8) → ?

# %%
print(10 == 10.0)
int(7.8)
# Out:
# True
# 7

# %% [markdown]
# ### class15

# %% [markdown]
# **que01:** Ek program banao jo name aur birth year poochhe, phir age print kare.

# %%
name = input("enter your name: ")
BOY = int(input("enter your birth year: "))

print(f"{name}'s age is {2026-BOY}")
# Out:
# shweta's age is 25

# %% [markdown]
# **que02:** Ek simple bill calculator: item price aur quantity poochho, total ₹ aur 2 decimals ke saath print karo.

# %%
price = int(input("enter price: "))
qty = int(input("enter quantity: "))

total = price*qty

print(f"the total cost is {total:.2f}")
# Out:
# the total cost is 800.00

# %% [markdown]
# **que03:** User se ek messy sentence maango, phir use stripped aur uppercase mein print karo.

# %%
sentence = input("enter sentence: ")
print(sentence.strip())
print(sentence.upper())
# Out:
# i am
#    I AM
