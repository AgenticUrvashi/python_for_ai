# %% [markdown]
# # class 3:if-else & loops

# %% [markdown]
# ### how to move the file into github?

# %% [markdown]
# Ans:

# %% [markdown]
# terminal pe jao fir envirment set ho to git likhake enter karo.fir git status type kare then enter.fir git add . karke enter kare.then git status karke check kare kya changes hai.then git commit -m "note" dalke enter kare. note me like "add file ka naam".git push origin to main likhake enter kare.
# in short:
# {  Git -> git status -> git add . -> git status (for checking) -> git commit -m “note” -> git push origin to main. }

# %% [markdown]
# github pe jake refresh kare fir hame chenges dikhenge.

# %% [markdown]
# how to download our code on git?

# %% [markdown]
# ans:terminal pr jaye fir jis folder me save karna hai uska path dekhe.git pr jake jo code download karna hai vo vaha jake code pr chick karo fir usme HTTPS pr jake path copy kar le.
# vapas terminal pr jake main folder ka naam type karke colon de fir enter kare. cd likhake next subfolder ko type kare or enter kare fir git clone likhake jo path hamane copy kiya vo paste kare or enter kare. fir vo aapke folder me download ho jayega.

# %% [markdown]
# how to delete the folder?

# %% [markdown]
# ans: terminal pr 'cd' likhake enter kare or fir 'rmdir /s file ka naam' ye likhana hai. '' nahi dena hai vo mane samjhne ke liye diye hai. or fir are you sure aayega to 'Y' likhana hai.

# %% [markdown]
# how to create feature branch?

# %% [markdown]
# ans: terminal pr jaye fir 'git checkout -b user/aapka naam/feature/week02 ' then enter. ab aap new branch switch ho chuki hai. dusra tarika ye ho sakta hai ki github pr jaye fir add existing respository pr click kare fir folder choose karna hai aur add respository pr click kare. left side jo box hai waha likho 'add week02' then enter kare. fir branch push kare.
# fir cursor me jake check kare likhe git status to aapko conferm ho jayega

# %% [markdown]
# ### CLASS 16 — if / elif / else & Truthiness

# %% [markdown]
# ### Concept 1 — if ka basic shape
#
#
# 📖 Technical definition — if / elif / else: A conditional statement runs a block of code only when its boolean condition is true. if tests the first condition, each elif tests a further condition when all previous ones were false, and else runs when none of the conditions were true. At most one block executes.

# %%
#ex.:
age = 19
if(age>= 18):
    print("drive_the_vehical")
# Out:
# drive_the_vehical

# %% [markdown]
# ### Concept 2 — else (warna ye karo)

# %%
age = 11
if(age>= 18):
    print("drive the vehical")
else:
    print("not drive")
# Out:
# not drive

# %%
age = 29
if(age>= 18):
    print("drive the vehical")
else:
    print("not drive")
# Out:
# drive the vehical

# %% [markdown]
# ### Concept 3 — elif (ek aur chance)

# %%
marks = 87

if marks >= 90:

    print("Grade A")

elif marks >= 75:

    print("Grade B")

elif marks >= 60:

    print("Grade C")

else:

    print("Grade D")
# Out:
# Grade B

# %% [markdown]
# ### Concept 4 — Truthiness (chupa hua superpower)
#
#
# 📖 Technical definition — Truthiness: Truthiness is the boolean value that any object takes on when used in a condition. Empty or zero-like values ("", 0, 0.0, [], {}, None) are treated as False; all other values are treated as True.

# %% [markdown]
# 0 >>>>> False
# 1 >>>>> True
# 10 >>>> True
# "A" >>>>> True
# "" >>>>> False
# {}>>>>> False
# [] >>>>> False
# none >>>> False

# %%
name =input("enter your name: ")

if name:
    print(f"hello!,{name}")

else:
    print("please enter your name")
# Out:
# hello!,janu

# %%
print("==============================check grade program=============================")
print("enter valid input numbers 1 to 100 and only charecter A.")

marks=input("enter your marks to get grade: ")

if marks == "A":
    print("student was absent")
elif marks >= str(90):
    print("grade A")
elif marks >= str(70):
    print("grade B")
elif marks >= str(50):
    print("grade C")
elif marks < str(50):
    print("grade D")
    print("failed")
# Out:
# ==============================check grade program=============================
# enter valid input numbers 1 to 100 and only charecter A.
# grade C

# %% [markdown]
# ### ❌ Common mistakes
#
# if marks >= 33          # ❌ colon ':' bhool gaye → SyntaxError
#
# print("Pass")           # ❌ indent nahi kiya → IndentationError
#
# if marks = 33:          # ❌ single '=' (store) use kiya, '==' (compare) chahiye tha

# %% [markdown]
# ## CLASS 17 — Nested Conditions & Ternary

# %% [markdown]
# ### Concept 1 — Nested if (if ke andar if)
#
#
#  Technical definition — Nested conditional: A nested conditional is an if statement placed inside the body of another if, elif, or else block, so that an inner condition is only tested when the outer condition has already been satisfied.

# %%
age = 20

drive_the_car = True

if age >= 18:

    if drive_the_car:

        print("give license!")

    else:

        print("don't give license")

else:

    print("Only 18+ allowed")
# Out:
# Running cells with '.venv (Python 3.15.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"g:/Urvashi/New folder/python_for_ai/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### Concept 2 — Aksar and zyada saaf hota hai

# %%
age = 20

drive_the_car = True

if age >= 18 and drive_the_car:

    print("give licence!")

else:

    print("Sorry, cannot give")

# %% [markdown]
# ### Concept 3 — Ternary (one-line if/else)
#
#
# Technical definition — Ternary (conditional) expression: A ternary expression is a single-line construct of the form value_if_true if condition else value_if_false that evaluates to one of two values depending on whether the condition is true.

# %%
age = 20

status = "Adult" if age >= 18 else "Minor"

print(status)

# %% [markdown]
# ##### Demo — ticket price by age

# %%
age = int(input("Enter your age: "))

if age < 5:

    price = 0

elif age < 18:

    price = 100

elif age < 60:

    price = 200

else:

    price = 50          # senior citizen discount

print(f"Ticket price: ₹{price}")

# %% [markdown]
# #### Common mistakes
# #galat order — chhota check pehle, toh bada kabhi nahi chalega
#
# if marks >= 33:
#
#     print("Pass")
#
# elif marks >= 90:    #yahan kabhi nahi aayega (33 already True ho gaya)
#
#     print("Grade A")

# %% [markdown]
# ## CLASS 18 — for Loops, range & Helpers

# %% [markdown]
# ### Concept 1 — for loop ek list par
#
#
# 📖 Technical definition — for loop: A for loop is an iteration statement that executes its body once for each item in an iterable (such as a list, string, or range), binding the current item to a loop variable on each pass.

# %%
fruits = ["apple", "banana", "mango"]

for fruit in fruits:

    print(fruit)

# %% [markdown]
# ### Concept 2 — range() — numbers banata hai
#
#
# 📖 Technical definition — range(): range() produces an immutable sequence of evenly spaced integers, defined by a start (default 0), a stop (exclusive), and a step (default 1). It is memory-efficient because it generates values on demand rather than storing them all.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ##### range ke 3 roop:
#
# range(5)        # 0,1,2,3,4         (stop)
#
# range(1, 6)     # 1,2,3,4,5         (start, stop)
#
# range(2, 11, 2) # 2,4,6,8,10        (start, stop, step)

# %% [markdown]
# ### Concept 4 — zip (do lists saath-saath)
#
#
# 📖 Technical definition — zip(): zip() combines two or more iterables element by element, yielding tuples of corresponding items. It stops as soon as the shortest input iterable is exhausted.

# %%
names = ["Asha", "Rahul", "Priya"]

marks = [85, 90, 78]

for name, mark in zip (names, marks):

    print(f"{name} scored {mark}")

# %% [markdown]
# ### Concept 3 — enumerate (number + item dono)
#
#
# 📖 Technical definition — enumerate(): enumerate() wraps an iterable and yields pairs of (index, item), providing an automatic counter alongside each element so you do not have to maintain one manually.

# %%
fruits = ["apple", "banana", "mango"]

for index, fruit in enumerate(fruits):

    print(f"{index}: {fruit}")

# %% [markdown]
# * [1 se shuru karna ho? enumerate(fruits, start=1) likho.]

# %% [markdown]
# ### Concept 4 — reversed (ulta chalo)

# %%
for i in reversed(range(1, 6)):

    print(i)        # 5, 4, 3, 2, 1

# %% [markdown]
# ##### Demo — multiplication table

# %%
num = int(input("Which table? "))

for i in range(1, 11):

    print(f"{num} x {i} = {num * i}")

# %% [markdown]
# ### Common mistakes
#
#
# for i in range(1, 5):
#
#     print(i)
# #indent bhool jaana
#
# for i in range(3):
#
# print(i)

# %% [markdown]
# ## CLASS 19 — while Loops & Loop Control

# %% [markdown]
# ### Concept 1 — while loop
#
#
# 📖 Technical definition — while loop: A while loop repeatedly executes its body as long as its boolean condition remains true. The condition is checked before each pass, so the body may run zero or more times.

# %%
count = 1

while count <= 5:

    print(count)

    count = count + 1      # yeh line BAHUT zaroori hai

# %% [markdown]
#  ### Concept 2 — infinite loop (sabse bada khatra)

# %% [markdown]
# count = 1
#
# while count <= 5:
#
#     print(count)
#
# #infinite loop me khara hai kyuki ye stop nahi hoti aur agar aap stop karna chaho to error aayga.

# %% [markdown]
# {Agar condition kabhi False na ho, loop HAMESHA chalta rahega — screen bhar jaayegi. Is infinite loop bolte hain. Rokne ke liye terminal mein Ctrl + C dabao. Hamesha confirm karo ki loop ke andar kuch condition ko False ki taraf le ja raha hai.}

# %% [markdown]
# ### Concept 3 — break aur continue
#
#
# 📖 Technical definition — break and continue: break immediately terminates the innermost enclosing loop. continue skips the rest of the current iteration and proceeds to the next pass of the loop.

# %% [markdown]
# * break = loop turant CHHOD do.
# * continue = yeh round CHHOD do, agle par chalo

# %%
for i in range(1,10):
    if i == 8:
        break
    print(i)

# %%
for i in range(0,10):
    if i % 2:
        continue
    print(i)

# %% [markdown]
# ### Concept 4 — pass (kuch mat karo, placeholder)

# %%
for i in range(3):
    pass

# %% [markdown]
# ### Concept 5 — any aur all
#
#
# 📖 Technical definition — any() and all(): any() returns True if at least one element of an iterable is truthy; all() returns True only if every element is truthy (and True for an empty iterable).

# %% [markdown]
# ##### all:

# %%
print(all(m >= 33 for m in marks))

n =["yes","true",1]
print(all(n))

m =["no","False",0]
print(all(m))
# Out:
# Running cells with '.venv (Python 3.15.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"g:/Urvashi/New folder/python_for_ai/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ##### any:

# %%
n = ["yes",True,0]
print(any(n))

m = [None,False,0]
print(any(m))

# %% [markdown]
# ### Common mistakes
#
#
# * 1) counter badhaana bhool jaana → infinite loop
#
# * 2) galat comparison
#
# count = 1
#
# while count = 5:

# %% [markdown]
# ### CLASS 20 — Nested Loops & match/case (Mini Projects)

# %% [markdown]
# #### Concept 1 — Nested loop (loop ke andar loop)
#
#
# 📖 Technical definition — Nested loop: A nested loop is a loop placed inside the body of another loop. For every single pass of the outer loop, the inner loop runs through all of its iterations completely.

# %%
for i in range(1, 4):

    for j in range(1, 4):

        print(f"{i}-{j}", end="  ")

    print()

# %% [markdown]
#  ### Concept 2 — match / case (saaf routing)
#
#
# 📖 Technical definition — match / case: Structural pattern matching compares a subject value against a series of case patterns and runs the block of the first pattern that matches. The wildcard pattern _ matches anything and acts as a default.

# %%
command = input("Enter command (start/stop/pause): ")

match command:

    case "start":

        print("Starting...")

    case "stop":

        print("Stopping...")

    case "pause":

        print("Pausing...")

    case _:

        print("Unknown command")
# Out:
# Starting...

# %% [markdown]
# ### Common mistakes
#
# #match mein colon aur indentation zaroori
#
# match x:
#
#     case 1
#
#         print("one")    #case ke baad ':' bhool gaye
